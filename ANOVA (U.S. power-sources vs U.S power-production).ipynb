# %%
# Dependencies
from matplotlib import pyplot as plt
from scipy.stats import linregress
import scipy.stats as stats
#import numpy as np
#from sklearn import datasets
import pandas as pd

# %%
filepath = "Resources/Net_generation_for_electric_power.csv"
data = pd.read_csv(filepath)
data.dropna(inplace=True)

columns = []
for col in data.columns:
    columns.append(col)
#New dataframe with only years from 2010 - 2020
data = data[['description', 'units', 'source key','Jan-10', 'Feb-10', 'Mar-10', 'Apr-10', 'May-10', 'Jun-10', 'Jul-10', 'Aug-10', 'Sep-10', 'Oct-10', 'Nov-10', 'Dec-10', 'Jan-11', 'Feb-11', 'Mar-11', 'Apr-11', 'May-11', 'Jun-11', 'Jul-11', 'Aug-11', 'Sep-11', 'Oct-11', 'Nov-11', 'Dec-11', 'Jan-12', 'Feb-12', 'Mar-12', 'Apr-12', 'May-12', 'Jun-12', 'Jul-12', 'Aug-12', 'Sep-12', 'Oct-12', 'Nov-12', 'Dec-12', 'Jan-13', 'Feb-13', 'Mar-13', 'Apr-13', 'May-13', 'Jun-13', 'Jul-13', 'Aug-13', 'Sep-13', 'Oct-13', 'Nov-13', 'Dec-13', 'Jan-14', 'Feb-14', 'Mar-14', 'Apr-14', 'May-14', 'Jun-14', 'Jul-14', 'Aug-14', 'Sep-14', 'Oct-14', 'Nov-14', 'Dec-14', 'Jan-15', 'Feb-15', 'Mar-15', 'Apr-15', 'May-15', 'Jun-15', 'Jul-15', 'Aug-15', 'Sep-15', 'Oct-15', 'Nov-15', 'Dec-15', 'Jan-16', 'Feb-16', 'Mar-16', 'Apr-16', 'May-16', 'Jun-16', 'Jul-16', 'Aug-16', 'Sep-16', 'Oct-16', 'Nov-16', 'Dec-16', 'Jan-17', 'Feb-17', 'Mar-17', 'Apr-17', 'May-17', 'Jun-17', 'Jul-17', 'Aug-17', 'Sep-17', 'Oct-17', 'Nov-17', 'Dec-17', 'Jan-18', 'Feb-18', 'Mar-18', 'Apr-18', 'May-18', 'Jun-18', 'Jul-18', 'Aug-18', 'Sep-18', 'Oct-18', 'Nov-18', 'Dec-18', 'Jan-19', 'Feb-19', 'Mar-19', 'Apr-19', 'May-19', 'Jun-19', 'Jul-19', 'Aug-19', 'Sep-19', 'Oct-19', 'Nov-19', 'Dec-19', 'Jan-20', 'Feb-20', 'Mar-20', 'Apr-20', 'May-20', 'Jun-20', 'Jul-20', 'Aug-20', 'Sep-20', 'Oct-20', 'Nov-20', 'Dec-20']].copy()
data.head()
# Out:
#                                  description                   units  \
# 2  United States : all fuels (utility-scale)  thousand megawatthours
# 3                       United States : coal  thousand megawatthours
# 4          United States : petroleum liquids  thousand megawatthours
# 5             United States : petroleum coke  thousand megawatthours
# 6                United States : natural gas  thousand megawatthours
#
#              source key  Jan-10  Feb-10  Mar-10  Apr-10  May-10  Jun-10  \
# 2  ELEC.GEN.ALL-US-98.M  348128  307994  299571  276121  315656  362985
# 3  ELEC.GEN.COW-US-98.M  171660  151461  142665  125615  141669  163912
# 4  ELEC.GEN.PEL-US-98.M    3073    1156    1202    1151    1776    2591
# 5   ELEC.GEN.PC-US-98.M    1038    1010    1097     958    1025    1202
# 6   ELEC.GEN.NG-US-98.M   66847   59556   56492   58124   66862   85033
#
#    Jul-10  ...  Mar-20  Apr-20  May-20  Jun-20  Jul-20  Aug-20  Sep-20  \
# 2  396195  ...  294084  264054  291979  340019  400737  386013  321755
# 3  177778  ...   50145   40189   46094   64920   89368   90814   67978
# 4    2886  ...     671     597     664     819     916     883     758
# 5    1313  ...     635     560     546     757     775     725     412
# 6  106961  ...  114766  100048  107853  134669  176293  164758  133123
#
#    Oct-20  Nov-20  Dec-20
# 2  301722  290110  331059
# 3   59440   60896   78215
# 4     861     761     868
# 5     278     589     689
# 6  123640  100783  116315
#
# [5 rows x 135 columns]

# %%
#New dataframe remove units & source key
df_data = data.copy()
to_drop = ['units', 'source key']
df_data.drop(to_drop, inplace=True, axis=1)

# %%
#Show new dataframe
df_data = df_data.reset_index()
df_data.drop(['index'], inplace=True, axis=1)
df_data
# Out:
#                                        description  Jan-10  Feb-10  Mar-10  \
# 0        United States : all fuels (utility-scale)  348128  307994  299571
# 1                             United States : coal  171660  151461  142665
# 2                United States : petroleum liquids    3073    1156    1202
# 3                   United States : petroleum coke    1038    1010    1097
# 4                      United States : natural gas   66847   59556   56492
# 5                      United States : other gases     275     247     275
# 6                          United States : nuclear   72569   65245   64635
# 7       United States : conventional hydroelectric   22207   20421   20691
# 8                 United States : other renewables   10480    8756   12300
# 9                             United States : wind    6853    5431    8588
# 10         United States : all utility-scale solar      10      33      76
# 11      United States : utility-scale photovoltaic       6      11      21
# 12           United States : utility-scale thermal       4      22      55
# 13                      United States : geothermal    1312    1159    1307
# 14                         United States : biomass    2305    2133    2330
# 15   United States : hydro-electric pumped storage    -565    -351    -325
# 16                           United States : other     543     492     539
# 17                       United States : all solar      --      --      --
# 18  United States : small-scale solar photovoltaic      --      --      --
# 19         United States : all utility-scale solar      10      33      76
# 20      United States : utility-scale photovoltaic       6      11      21
# 21           United States : utility-scale thermal       4      22      55
# 22          California : all fuels (utility-scale)   14211   13404   14659
# 23                               California : coal     163     160      94
# 24                  California : petroleum liquids       4       4       4
# 25                     California : petroleum coke      91      81      95
# 26                        California : natural gas    8590    7916    8410
# 27                        California : other gases       6       5       5
# 28                            California : nuclear    2384    2218    2138
# 29         California : conventional hydroelectric    1327    1447    2038
# 30                   California : other renewables    1688    1626    1926
# 31                               California : wind     150     221     399
# 32            California : all utility-scale solar       2      20      51
# 33         California : utility-scale photovoltaic       0       3       7
# 34              California : utility-scale thermal       2      18      44
# 35                         California : geothermal    1104     991    1082
# 36                            California : biomass     432     394     395
# 37      California : hydro-electric pumped storage     -60     -70     -68
# 38                              California : other      19      17      17
# 39                          California : all solar      --      --      --
# 40     California : small-scale solar photovoltaic      --      --      --
# 41            California : all utility-scale solar       2      20      51
# 42         California : utility-scale photovoltaic       0       3       7
# 43              California : utility-scale thermal       2      18      44
#
#     Apr-10  May-10  Jun-10  Jul-10  Aug-10  Sep-10  ...  Mar-20  Apr-20  \
# 0   276121  315656  362985  396195  394651  333057  ...  294084  264054
# 1   125615  141669  163912  177778  175848  147157  ...   50145   40189
# 2     1151    1776    2591    2886    2352    1608  ...     671     597
# 3      958    1025    1202    1313    1023    1000  ...     635     560
# 4    58124   66862   85033  106961  112961   85498  ...  114766  100048
# 5      273     279     265     267     249     240  ...     288     150
# 6    57611   66658   68301   71913   71574   69371  ...   63997   59170
# 7    18898   24903   29711   24405   20019   17188  ...   23483   22002
# 8    13286   12349   11851   10637   10624   10832  ...   39791   41036
# 9     9763    8696    8048    6723    6685    7104  ...   29496   29386
# 10     112     153     175     161     156     137  ...    6436    8052
# 11      34      43      51      46      49      48  ...    6243    7746
# 12      78     110     124     114     107      89  ...     193     306
# 13    1240    1311    1264    1274    1297    1253  ...    1473    1410
# 14    2171    2189    2364    2480    2487    2338  ...    2386    2187
# 15    -335    -441    -472    -557    -600    -421  ...    -353    -325
# 16     541     574     592     592     599     585  ...     662     629
# 17      --      --      --      --      --      --  ...      --      --
# 18      --      --      --      --      --      --  ...      --      --
# 19     112     153     175     161     156     137  ...    6436    8052
# 20      34      43      51      46      49      48  ...    6243    7746
# 21      78     110     124     114     107      89  ...     193     306
# 22   14308   14643   14975   18314   18978   16893  ...   13376   12612
# 23     141     147     156     165     150     156  ...       0       0
# 24       3       3       7       4       3       4  ...       3       2
# 25      82      81      90      77      78      81  ...       0       0
# 26    6987    4876    4474    7850    9428    8618  ...    5738    3773
# 27       4       5       5       5       4       1  ...       0       0
# 28    2500    3355    3269    3378    3382    3237  ...    1671    1631
# 29    2580    3945    4439    4175    3519    2642  ...    1222    1983
# 30    2004    2203    2458    2567    2369    2110  ...    4781    5255
# 31     546     689     867     925     731     551  ...    1174    1169
# 32      75     106     121     116     104      86  ...    2155    2705
# 33      11      15      18      17      15      13  ...    2026    2496
# 34      65      91     103      99      89      73  ...     129     209
# 35    1021    1073    1038    1064    1069    1038  ...    1072    1017
# 36     363     336     432     462     463     436  ...     380     363
# 37      -7      10      58      73      25      26  ...     -53     -47
# 38      13      18      18      20      20      17  ...      14      14
# 39      --      --      --      --      --      --  ...      --      --
# 40      --      --      --      --      --      --  ...      --      --
# 41      75     106     121     116     104      86  ...    2155    2705
# 42      11      15      18      17      15      13  ...    2026    2496
# 43      65      91     103      99      89      73  ...     129     209
#
#     May-20  Jun-20  Jul-20  Aug-20  Sep-20  Oct-20  Nov-20  Dec-20
# 0   291979  340019  400737  386013  321755  301722  290110  331059
# 1    46094   64920   89368   90814   67978   59440   60896   78215
# 2      664     819     916     883     758     861     761     868
# 3      546     757     775     725     412     278     589     689
# 4   107853  134669  176293  164758  133123  123640  100783  116315
# 5      161     133     162     303     297     238     306     337
# 6    64338   67205   69385   68982   65727   59362   61760   69871
# 7    30367   28950   27571   23985   19076   18237   21736   22981
# 8    41698   42492   36307   35692   34314   39494   43050   41486
# 9    28282   29446   22186   22341   22977   28770   33582   32329
# 10    9679    9555   10386    9428    7824    7284    5845    5338
# 11    9266    9184    9956    9071    7554    7025    5681    5246
# 12     413     371     430     356     270     259     164      92
# 13    1411    1338    1404    1400    1359    1341    1448    1434
# 14    2326    2154    2331    2524    2154    2099    2175    2385
# 15    -367    -499    -686    -784    -525    -423    -369    -368
# 16     626     572     646     653     595     594     598     665
# 17      --      --      --      --      --      --      --      --
# 18      --      --      --      --      --      --      --      --
# 19    9679    9555   10386    9428    7824    7284    5845    5338
# 20    9266    9184    9956    9071    7554    7025    5681    5246
# 21     413     371     430     356     270     259     164      92
# 22   14013   15441   18151   20307   16773   15779   13074   13512
# 23       0       0       0       0       0       0       0       0
# 24       2       3       4       6       3       4       3       3
# 25       0       0       0       0       0       0       0       0
# 26    3536    5262    7887   10497    8739    9241    6844    7593
# 27       0       0       0       0       0       0       0       0
# 28    1598    1628    1279    1598    1600     439     784     857
# 29    2747    2534    2630    2626    1728    1382    1030     853
# 30    6119    5954    6264    5578    4691    4719    4402    4170
# 31    1339    1270    1230    1033     819    1099    1164    1136
# 32    3385    3354    3618    3119    2521    2312    1854    1613
# 33    3087    3090    3298    2860    2332    2127    1731    1554
# 34     298     263     320     259     189     185     123      59
# 35    1024     973    1033    1031     990     967    1045    1032
# 36     370     357     384     395     361     342     338     389
# 37       2      54      69     -12      -1     -18      -1      25
# 38       9       5      17      14      12      14      12      11
# 39      --      --      --      --      --      --      --      --
# 40      --      --      --      --      --      --      --      --
# 41    3385    3354    3618    3119    2521    2312    1854    1613
# 42    3087    3090    3298    2860    2332    2127    1731    1554
# 43     298     263     320     259     189     185     123      59
#
# [44 rows x 133 columns]

# %%
#Massage the data using pandas.melt()
#description is id_vars and each month is value_vars
#pd.melt(df_data, id_vars=['description'], value_vars=[''])
columns_name = df_data.columns.values.tolist()
columns_name.remove(columns_name[0])
value_vars=columns_name
id_vars='description'

data = pd.melt(df_data, id_vars=['description'], value_vars=value_vars).drop(columns=['variable'])
data = data.replace('--', 0)
data = data.replace('NM', 0)
data["value"] = pd.to_numeric(data["value"], downcast="float")
data = data.rename(columns={'description':'United States Power Source', 'value': 'Energy Production (Thousand Megawatthours)'})

# %%
#Extract ONLY U.S. power-sources from dataframe and Remove "United States :" from Power Source column
data = data.loc[data['United States Power Source'].str.contains('United States')]
data['United States Power Source'] = data['United States Power Source'].str.lstrip('United States')
data['United States Power Source'] = data['United States Power Source'].str.lstrip(':')
data['United States Power Source'] = data['United States Power Source'].str.title()

# %%
#list of power source names
power_source_names = data['United States Power Source'].unique().tolist()
len(power_source_names)
data.head()
# Out:
#    United States Power Source  Energy Production (Thousand Megawatthours)
# 0   All Fuels (Utility-Scale)                                    348128.0
# 1                        Coal                                    171660.0
# 2           Petroleum Liquids                                      3073.0
# 3              Petroleum Coke                                      1038.0
# 4                 Natural Gas                                     66847.0

# %%
#ANOVA sample variance between means of each power-source
data.boxplot(column='Energy Production (Thousand Megawatthours)', by='Power Source', figsize=(90,25), grid=False, fontsize='18')
plt.savefig('Images/Box-Plot U.S. Energy Production Years 2010-2020.png', transparent=False, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-4b3dd3ba3545> in <module>
#       1 #ANOVA sample variance between means of each power-source
# ----> 2 data.boxplot(column='Energy Production (Thousand Megawatthours)', by='Power Source', figsize=(90,25), grid=False, fontsize='18')
#       3 plt.savefig('Images/Box-Plot U.S. Energy Production Years 2010-2020.png', transparent=False, bbox_inches='tight')
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     492 ):
#     493     plot_backend = _get_plot_backend(backend)
# --> 494     return plot_backend.boxplot_frame(
#     495         self,
#     496         column=column,
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\boxplot.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     383     import matplotlib.pyplot as plt
#     384
# --> 385     ax = boxplot(
#     386         self,
#     387         column=column,
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\boxplot.py in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     335         # Prefer array return type for 2-D plots to match the subplot layout
#     336         # https://github.com/pandas-dev/pandas/pull/12216#issuecomment-241175580
# --> 337         result = _grouped_plot_by_column(
#     338             plot_group,
#     339             data,
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\boxplot.py in _grouped_plot_by_column(plotf, data, columns, by, numeric_only, grid, figsize, ax, layout, return_type, **kwargs)
#     196     **kwargs,
#     197 ):
# --> 198     grouped = data.groupby(by)
#     199     if columns is None:
#     200         if not isinstance(by, (list, tuple)):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# --> 560             grouper, exclusions, obj = get_grouper(
#     561                 obj,
#     562                 keys,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     809                 in_axis, name, level, gpr = False, None, gpr, None
#     810             else:
# --> 811                 raise KeyError(gpr)
#     812         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     813             # Add key to exclusions
#
# KeyError: 'Power Source'

# %%
#Extract individual groups for U.S. power-sources U.S total groups: 19

def extract(power_source):
    
    pop = data[data['Power Source']==power_source]['Energy Production (Thousand Megawatthours)']
    pop
    return pop
    
    return group

group1 = extract(power_source_names[0])
group2 = extract(power_source_names[1])
group3 = extract(power_source_names[2])
group4 = extract(power_source_names[3])
group5 = extract(power_source_names[4])
group6 = extract(power_source_names[5])
group7 = extract(power_source_names[6])
group8 = extract(power_source_names[7])
group9 = extract(power_source_names[8])
group10 = extract(power_source_names[9])
group11 = extract(power_source_names[10])
group12 = extract(power_source_names[11])
group13 = extract(power_source_names[12])
group14 = extract(power_source_names[13])
group15 = extract(power_source_names[14])
group16 = extract(power_source_names[15])
group17 = extract(power_source_names[16])
group18 = extract(power_source_names[17])
group19 = extract(power_source_names[18])

# %%
#ANOVA Test
stats.f_oneway(group2, group3, group4, group5, group6, group7, group8, group9, group10, group11, group12, group13, group14, group15, group16, group17, group18, group19)
